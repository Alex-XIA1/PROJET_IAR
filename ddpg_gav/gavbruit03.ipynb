# %%
# Installs the necessary Python and system libraries
try:
    from easypip import easyimport, easyinstall, is_notebook
except ModuleNotFoundError as e:
    get_ipython().run_line_magic("pip", "install easypip")
    from easypip import easyimport, easyinstall, is_notebook

easyinstall("bbrl>=0.2.2")
easyinstall("swig")
easyinstall("bbrl_gymnasium>=0.2.0")
easyinstall("bbrl_gymnasium[box2d]")
easyinstall("bbrl_gymnasium[classic_control]")
easyinstall("tensorboard")
easyinstall("moviepy")
easyinstall("box2d-kengz")
# Out:
# [notice] A new release of pip is available: 23.3 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import sys
from pathlib import Path
import math

from moviepy.editor import ipython_display as video_display
import time
from tqdm.auto import tqdm
from typing import Tuple, Optional
from functools import partial

from omegaconf import OmegaConf
import torch
import bbrl_gymnasium

import copy
from abc import abstractmethod, ABC
import torch.nn as nn
import torch.nn.functional as F
from time import strftime
OmegaConf.register_new_resolver(
    "current_time", lambda: strftime("%Y%m%d-%H%M%S"), replace=True
)
from bbrl.agents.gymnasium import GymAgent, ParallelGymAgent, make_env, record_video

# %%
from datetime import datetime
from datetime import date

import base64
import glob
import io
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay

import gymnasium
from gymnasium import logger as gymlogger
# from gym.wrappers import Monitor # deprecated 2023 - https://stackoverflow.com/questions/71520568/importerror-cannot-import-name-monitor-from-gym-wrappers
from gymnasium.wrappers.record_video import RecordVideo
gymlogger.set_level(40) #error only
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

print("\n",date.today(), datetime.now().strftime("%H:%M:%S"),"GMT") # timestamp is greenwich time
print("OK.")

def show_video(loop=True, num=0):
    mp4list = glob.glob(f'videoTest/rl-video-episode-{num}.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        if loop == True:
            ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:videoTest/mp4;base64,{0}" type="video/mp4" />
                 </video>'''.format(encoded.decode('ascii'))))
        else:
            ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    controls style="height: 400px;">
                    <source src="data:videoTest/mp4;base64,{0}" type="video/mp4" />
                 </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")
    
def wrap_env(env):
    env = RecordVideo(env, './videoTest',  episode_trigger = lambda episode_number: True) # !!! 2023
    env.reset() # !!! 2023
    #env = Monitor(env, './video', force=True)
    return env
# Out:
#  2024-01-12 11:32:26 GMT
# OK.

# %%
"""
Continuous action version of the classic cart-pole system implemented by Rich
Sutton et al.
"""
import math

import numpy as np

from gymnasium.envs.classic_control.cartpole import CartPoleEnv
from gymnasium import logger, spaces
from gymnasium.wrappers import TimeLimit

import sys
sys.modules[__name__]

class ContinuousEnvCACLA(CartPoleEnv):
    """Continuous version  of the CartPole-v1 environment"""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.min_action = -1
        self.max_action = 1
        self.action_space = spaces.Box(
            self.min_action, self.max_action, shape=(1,), dtype=np.float64
        )
        

    def step(self, action):
        if action > self.max_action:
            action = np.array(self.max_action)
        elif action < self.min_action:
            action = np.array(self.min_action)
        assert self.state is not None, "Call reset before using step method."

        x, x_dot, theta, theta_dot = self.state
        force = self.force_mag * float(action)

        costheta = math.cos(theta)
        sintheta = math.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * theta_dot**2 * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length * (4.0 / 3.0 - self.masspole * costheta**2 / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        if self.kinematics_integrator == "euler":
            x = x + self.tau * x_dot
            x_dot = x_dot + self.tau * xacc
            theta = theta + self.tau * theta_dot
            theta_dot = theta_dot + self.tau * thetaacc
        else:  # semi-implicit euler
            x_dot = x_dot + self.tau * xacc
            x = x + self.tau * x_dot
            theta_dot = theta_dot + self.tau * thetaacc
            theta = theta + self.tau * theta_dot

        self.state = (x, x_dot, theta, theta_dot)

        terminated = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        if not terminated:
            reward = 1.0
        elif self.steps_beyond_terminated is None:
            # Pole just fell!
            self.steps_beyond_terminated = 0
            reward = -1.0
        else:
            if self.steps_beyond_terminated == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned terminated = True. You "
                    "should always call 'reset()' once you receive 'terminated = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_terminated += 1
            reward = 0

        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), reward, terminated, False, {}

try:
  gymnasium.envs.register(
      id='CartpoleEnvCacla',
      entry_point='__main__:ContinuousEnvCACLA',
      max_episode_steps=500
  )
except:
    print("Except")
    pass

# %%
import torch.nn
import numpy as np
from torch.optim import SGD, Adam
class Gav(nn.Module):
    def __init__(self, in_dim, h_dim, activation=nn.Tanh, discount_factor=0.95, gaussian_noise=0.01, lrate = 0.01, decay=0.99, exploration="gaussian"):
        super(Gav,self).__init__()
        self.critic = nn.Sequential(
            nn.Linear(in_dim+1, h_dim),
            activation(),
            nn.Linear(h_dim, 1)
        )
        self.critic_optim = Adam(self.critic.parameters(), lr=lrate)
        
        self.actor = nn.Sequential(
            nn.Linear(in_dim, h_dim),
            activation(),
            nn.Linear(h_dim, 1),
            activation()
        )
        self.actor_optim = Adam(self.actor.parameters(), lr=lrate)
        
        self.discount_factor = discount_factor
        self.gaussian_noise = gaussian_noise
        self.e = 1
        self.prob_update = 1
        self.decay_rate = decay
        self.exploration = exploration
    
    def forward(self, x):
        x = torch.from_numpy(x).unsqueeze(0)
        # le critic prend aussi l'action
        act = self.actor(x)
        act = normalize(act)
        # gaussian exploration
        if self.exploration=="gaussian": act = self.sample(act)
        # egreedy exploration
        elif self.exploration=="egreedy" and torch.rand(1) < self.e: act = self.greed()
        x = torch.hstack((x,act))
        return self.critic(x), act
    
    def sample(self, x):
        return (x + np.random.normal(0,self.gaussian_noise))
    
    # nombre entre -1 et 1
    def greed(self):
        return (2 * torch.rand(1) - 1).unsqueeze(0)
    
    def decaye(self):
        self.e*=0.999
        self.e = max(0.01,self.e)
    
    def decay(self):
        self.prob_update*= self.decay_rate
        self.prob_update = max(0.01, self.prob_update)

        
def normalize(x):
    
    #normact = 2*((x+0.91351861)/(0.75200462 + 0.91351861))-1
    # bornes article
    #normact = 2*((x+2.70117164)/(2.76748848 + 2.70117164))-1
    normact = 2*((x+6)/(6 + 6))-1
    #print("Norm act ",normact)
    return normact

def normalize_obs(x):
    
    #bornes = np.array([2.44753194, -2.45538521, 0.2296841, -0.24339156, 2.99952817, -3.0505054, 1.55276, -2.181077])
    
    # bornes pour l'environnement de l'article
    #bornes = np.array([1.22236145, -1.22290611,  0.41785294, -0.47710252,  3.41861892, -2.79673457, 3.13325334, -4.49813938])
    bornes = np.array([4.8, -4.8,  2, -2, 4.1887903e-01, -4.1887903e-01, 2, -2])
    res = np.zeros(4, dtype=np.float32)
    #print("before ",x)
    res[0] = 2*((x[0]-bornes[1])/(bornes[0]-bornes[1]))-1
    res[1] = 2*((x[1]-bornes[3])/(bornes[2]-bornes[3]))-1
    res[2] = 2*((x[2]-bornes[5])/(bornes[4]-bornes[5]))-1
    res[3] = 2*((x[3]-bornes[7])/(bornes[6]-bornes[7]))-1
    
    #print(res[1])
    
    #print("res after ",res)
    return res

def normalize_critic(x):
    
    #return 2*((x+0.19350152)/(11.54955292 + 0.19350152))-1
    # bornes article
    #return 2*((x+8.18684864)/(6.95543098 + 8.18684864))-1
    return 2*((x+50)/(50 + 50))-1

def test(eval_env, model, n_test = 10):
    cum_reward = 0
    with torch.no_grad():
        for _ in range(n_test):
            done, truncated = False, False
            obs0,_ = eval_env.reset()
            while not done and not truncated:
                #obs0 = normalize_obs(obs0)
                _, a0 = model(obs0)  
                obs0, reward, done,truncated,_ = eval_env.step(normalize(a0))
                #obs0, reward, done,truncated,_ = eval_env.step(a0)
                cum_reward += reward
    return cum_reward/n_test
    
def train(eval_env, train_env, model, eval_interval=5000, step_max=100000, exploration="gaussian"):
    it = 0
    obs,_ = train_env.reset()
    p = 1
    scores = np.array([0])
    while it < step_max:
        it += 1
        #obs = normalize_obs(obs)
        model.critic_optim.zero_grad()
            
        q0, action = model(obs)
        #q0 = normalize_critic(q0)
        
        
        obs, reward, done, truncated, reste = train_env.step(action+np.random.normal(0,0.3)) 
        #obs = normalize_obs(obs)
        reward = model.sample(reward+np.random.normal(0,0.3))
        q1, _ = model(obs)
        #q1 = normalize_critic(q1)
        delta = reward + model.discount_factor*q1.detach() - q0
        (delta**2).backward()
        model.critic_optim.step()
        if torch.rand(1) > model.prob_update: 
            model.actor_optim.zero_grad()
            (-model(obs)[0]).backward()
            model.actor_optim.step()
        model.decay()
        # pour diminuer exponentiellement
        model.decaye()
        
        if done or truncated: obs,_ = train_env.reset()
        if it % eval_interval == 0:
            perf = test(eval_env, model)
            print(f'{it = } | reward {perf}')
            scores = np.hstack((scores,perf))
    return scores

# %%
# Initialisation
n_runs = 20
final = []
explo = "gaussian"
for run in range(n_runs):
    train_env = gymnasium.make('CartpoleEnvCacla')
    train_env = TimeLimit(train_env, max_episode_steps=500)
    eval_env = gymnasium.make('CartpoleEnvCacla')
    eval_env = TimeLimit(eval_env, max_episode_steps=500)
    print(f'======= {run = } / {n_runs-1} =========')
    gav = Gav(in_dim=4, h_dim=12, 
              discount_factor=0.95, 
              gaussian_noise=0.1,exploration =explo)
    scores = train(eval_env, train_env, gav, eval_interval=1024, step_max=102400)
    print(scores.shape)
    final.append(scores)

final = np.array(final)
np.savetxt("gav"+explo+".txt",final)
# Out:
# ======= run = 0 / 19 =========
# it = 1024 | reward 36.3
# it = 2048 | reward 44.8
# it = 3072 | reward 47.4
# it = 4096 | reward 38.1
# it = 5120 | reward 53.4
# it = 6144 | reward 79.1
# it = 7168 | reward 48.5
# it = 8192 | reward 49.1
# it = 9216 | reward 204.5
# it = 10240 | reward 132.7
# it = 11264 | reward 62.3
# it = 12288 | reward 62.0
# it = 13312 | reward 48.9
# it = 14336 | reward 42.1
# it = 15360 | reward 51.1
# it = 16384 | reward 42.6
# it = 17408 | reward 159.2
# it = 18432 | reward 133.4
# it = 19456 | reward 53.0
# it = 20480 | reward 143.4
# it = 21504 | reward 140.1
# it = 22528 | reward 38.4
# it = 23552 | reward 58.3
# it = 24576 | reward 47.8
# it = 25600 | reward 182.4
# it = 26624 | reward 234.1
# it = 27648 | reward 43.1
# it = 28672 | reward 47.4
# it = 29696 | reward 63.7
# it = 30720 | reward 199.9
# it = 31744 | reward 44.5
# it = 32768 | reward 43.3
# it = 33792 | reward 178.8
# it = 34816 | reward 43.6
# it = 35840 | reward 50.9
# it = 36864 | reward 55.6
# it = 37888 | reward 56.1
# it = 38912 | reward 320.9
# it = 39936 | reward 57.9
# it = 40960 | reward 51.9
# it = 41984 | reward 51.9
# it = 43008 | reward 42.4
# it = 44032 | reward 52.1
# it = 45056 | reward 52.1
# it = 46080 | reward 53.7
# it = 47104 | reward 43.3
# it = 48128 | reward 179.4
# it = 49152 | reward 95.4
# it = 50176 | reward 79.1
# it = 51200 | reward 117.0
# it = 52224 | reward 79.8
# it = 53248 | reward 155.7
# it = 54272 | reward 64.3
# it = 55296 | reward 112.5
# it = 56320 | reward 55.9
# it = 57344 | reward 59.5
# it = 58368 | reward 48.7
# it = 59392 | reward 45.2
# it = 60416 | reward 142.8
# it = 61440 | reward 409.1
# it = 62464 | reward 103.2
# it = 63488 | reward 54.7
# it = 64512 | reward 93.2
# it = 65536 | reward 178.6
# it = 66560 | reward 121.9
# it = 67584 | reward 59.3
# it = 68608 | reward 40.6
# it = 69632 | reward 73.8
# it = 70656 | reward 61.1
# it = 71680 | reward 71.4
# it = 72704 | reward 72.6
# it = 73728 | reward 62.4
# it = 74752 | reward 61.1
# it = 75776 | reward 56.7
# it = 76800 | reward 305.2
# it = 77824 | reward 63.3
# it = 78848 | reward 58.0
# it = 79872 | reward 56.2
# it = 80896 | reward 165.8
# it = 81920 | reward 49.4
# it = 82944 | reward 64.8
# it = 83968 | reward 53.7
# it = 84992 | reward 89.1
# it = 86016 | reward 70.7
# it = 87040 | reward 212.9
# it = 88064 | reward 252.0
# it = 89088 | reward 113.6
# it = 90112 | reward 169.6
# it = 91136 | reward 252.6
# it = 92160 | reward 195.6
# it = 93184 | reward 46.3
# it = 94208 | reward 56.7
# it = 95232 | reward 52.2
# it = 96256 | reward 49.3
# it = 97280 | reward 106.8
# it = 98304 | reward 210.5
# it = 99328 | reward 156.0
# it = 100352 | reward 41.3
# it = 101376 | reward 64.1
# it = 102400 | reward 173.4
# (101,)
# ======= run = 1 / 19 =========
# it = 1024 | reward 61.8
# it = 2048 | reward 48.9
# it = 3072 | reward 56.6
# it = 4096 | reward 86.3
# it = 5120 | reward 65.2
# it = 6144 | reward 57.9
# it = 7168 | reward 61.7
# it = 8192 | reward 42.5
# it = 9216 | reward 45.6
# it = 10240 | reward 46.2
# it = 11264 | reward 48.1
# it = 12288 | reward 83.5
# it = 13312 | reward 110.5
# it = 14336 | reward 46.7
# it = 15360 | reward 63.9
# it = 16384 | reward 46.0
# it = 17408 | reward 51.0
# it = 18432 | reward 42.3
# it = 19456 | reward 40.2
# it = 20480 | reward 38.2
# it = 21504 | reward 86.3
# it = 22528 | reward 257.3
# it = 23552 | reward 60.3
# it = 24576 | reward 53.6
# it = 25600 | reward 44.6
# it = 26624 | reward 39.7
# it = 27648 | reward 43.8
# it = 28672 | reward 43.3
# it = 29696 | reward 136.4
# it = 30720 | reward 64.4
# it = 31744 | reward 238.6
# it = 32768 | reward 199.4
# it = 33792 | reward 42.4
# it = 34816 | reward 232.5
# it = 35840 | reward 55.9
# it = 36864 | reward 54.7
# it = 37888 | reward 40.2
# it = 38912 | reward 76.2
# it = 39936 | reward 46.7
# it = 40960 | reward 49.0
# it = 41984 | reward 51.1
# it = 43008 | reward 56.2
# it = 44032 | reward 75.1
# it = 45056 | reward 94.3
# it = 46080 | reward 58.8
# it = 47104 | reward 55.4
# it = 48128 | reward 299.1
# it = 49152 | reward 138.9
# it = 50176 | reward 152.4
# it = 51200 | reward 248.7
# it = 52224 | reward 54.0
# it = 53248 | reward 186.6
# it = 54272 | reward 236.3
# it = 55296 | reward 185.9
# it = 56320 | reward 130.8
# it = 57344 | reward 45.8
# it = 58368 | reward 47.2
# it = 59392 | reward 49.9
# it = 60416 | reward 153.6
# it = 61440 | reward 51.2
# it = 62464 | reward 45.4
# it = 63488 | reward 186.1
# it = 64512 | reward 44.9
# it = 65536 | reward 57.0
# it = 66560 | reward 54.8
# it = 67584 | reward 52.3
# it = 68608 | reward 54.6
# it = 69632 | reward 62.8
# it = 70656 | reward 189.0
# it = 71680 | reward 51.8
# it = 72704 | reward 48.5
# it = 73728 | reward 100.4
# it = 74752 | reward 53.7
# it = 75776 | reward 105.4
# it = 76800 | reward 46.2
# it = 77824 | reward 61.3
# it = 78848 | reward 63.4
# it = 79872 | reward 187.5
# it = 80896 | reward 288.9
# it = 81920 | reward 136.7
# it = 82944 | reward 269.4
# it = 83968 | reward 110.3
# it = 84992 | reward 144.6
# it = 86016 | reward 56.4
# it = 87040 | reward 332.5
# it = 88064 | reward 276.3
# it = 89088 | reward 54.3
# it = 90112 | reward 54.5
# it = 91136 | reward 67.9
# it = 92160 | reward 54.7
# it = 93184 | reward 71.7
# it = 94208 | reward 147.1
# it = 95232 | reward 191.3
# it = 96256 | reward 56.9
# it = 97280 | reward 91.5
# it = 98304 | reward 83.9
# it = 99328 | reward 49.4
# it = 100352 | reward 236.4
# it = 101376 | reward 316.3
# it = 102400 | reward 315.8
# (101,)
# ======= run = 2 / 19 =========
# it = 1024 | reward 39.6
# it = 2048 | reward 37.5
# it = 3072 | reward 36.2
# it = 4096 | reward 37.9
# it = 5120 | reward 34.3
# it = 6144 | reward 34.4
# it = 7168 | reward 37.8
# it = 8192 | reward 31.5
# it = 9216 | reward 110.2
# it = 10240 | reward 44.3
# it = 11264 | reward 47.8
# it = 12288 | reward 57.7
# it = 13312 | reward 132.5
# it = 14336 | reward 47.7
# it = 15360 | reward 73.5
# it = 16384 | reward 71.0
# it = 17408 | reward 52.1
# it = 18432 | reward 45.9
# it = 19456 | reward 49.0
# it = 20480 | reward 172.3
# it = 21504 | reward 61.4
# it = 22528 | reward 194.1
# it = 23552 | reward 45.6
# it = 24576 | reward 60.5
# it = 25600 | reward 44.2
# it = 26624 | reward 187.2
# it = 27648 | reward 57.8
# it = 28672 | reward 47.4
# it = 29696 | reward 63.4
# it = 30720 | reward 61.7
# it = 31744 | reward 41.2
# it = 32768 | reward 44.1
# it = 33792 | reward 59.2
# it = 34816 | reward 252.2
# it = 35840 | reward 201.5
# it = 36864 | reward 48.0
# it = 37888 | reward 53.1
# it = 38912 | reward 51.7
# it = 39936 | reward 59.8
# it = 40960 | reward 56.5
# it = 41984 | reward 55.6
# it = 43008 | reward 63.7
# it = 44032 | reward 76.3
# it = 45056 | reward 228.5
# it = 46080 | reward 51.9
# it = 47104 | reward 54.7
# it = 48128 | reward 44.7
# it = 49152 | reward 43.8
# it = 50176 | reward 46.2
# it = 51200 | reward 46.7
# it = 52224 | reward 280.2
# it = 53248 | reward 44.2
# it = 54272 | reward 50.9
# it = 55296 | reward 71.5
# it = 56320 | reward 46.6
# it = 57344 | reward 38.0
# it = 58368 | reward 51.8
# it = 59392 | reward 38.1
# it = 60416 | reward 50.6
# it = 61440 | reward 46.0
# it = 62464 | reward 49.5
# it = 63488 | reward 51.5
# it = 64512 | reward 50.1
# it = 65536 | reward 93.1
# it = 66560 | reward 50.3
# it = 67584 | reward 51.1
# it = 68608 | reward 54.9
# it = 69632 | reward 179.7
# it = 70656 | reward 198.6
# it = 71680 | reward 219.2
# it = 72704 | reward 62.0
# it = 73728 | reward 255.4
# it = 74752 | reward 289.3
# it = 75776 | reward 225.3
# it = 76800 | reward 236.1
# it = 77824 | reward 414.3
# it = 78848 | reward 130.9
# it = 79872 | reward 40.6
# it = 80896 | reward 44.0
# it = 81920 | reward 46.8
# it = 82944 | reward 62.2
# it = 83968 | reward 58.3
# it = 84992 | reward 39.7
# it = 86016 | reward 47.9
# it = 87040 | reward 93.3
# it = 88064 | reward 130.3
# it = 89088 | reward 112.9
# it = 90112 | reward 66.0
# it = 91136 | reward 66.0
# it = 92160 | reward 69.6
# it = 93184 | reward 67.8
# it = 94208 | reward 52.7
# it = 95232 | reward 198.9
# it = 96256 | reward 50.1
# it = 97280 | reward 46.8
# it = 98304 | reward 54.2
# it = 99328 | reward 247.9
# it = 100352 | reward 231.1
# it = 101376 | reward 296.2
# it = 102400 | reward 43.9
# (101,)
# ======= run = 3 / 19 =========
# it = 1024 | reward 36.9
# it = 2048 | reward 41.4
# it = 3072 | reward 32.7
# it = 4096 | reward 39.9
# it = 5120 | reward 38.5
# it = 6144 | reward 69.7
# it = 7168 | reward 47.0
# it = 8192 | reward 98.1
# it = 9216 | reward 41.3
# it = 10240 | reward 135.1
# it = 11264 | reward 102.3
# it = 12288 | reward 135.6
# it = 13312 | reward 50.6
# it = 14336 | reward 39.1
# it = 15360 | reward 53.0
# it = 16384 | reward 53.7
# it = 17408 | reward 54.5
# it = 18432 | reward 59.7
# it = 19456 | reward 356.4
# it = 20480 | reward 221.5
# it = 21504 | reward 88.5
# it = 22528 | reward 48.7
# it = 23552 | reward 214.4
# it = 24576 | reward 147.3
# it = 25600 | reward 47.3
# it = 26624 | reward 49.0
# it = 27648 | reward 58.4
# it = 28672 | reward 40.3
# it = 29696 | reward 53.1
# it = 30720 | reward 331.5
# it = 31744 | reward 45.4
# it = 32768 | reward 48.4
# it = 33792 | reward 62.6
# it = 34816 | reward 61.2
# it = 35840 | reward 169.8
# it = 36864 | reward 217.1
# it = 37888 | reward 49.8
# it = 38912 | reward 40.6
# it = 39936 | reward 50.7
# it = 40960 | reward 42.1
# it = 41984 | reward 119.4
# it = 43008 | reward 52.2
# it = 44032 | reward 50.0
# it = 45056 | reward 47.7
# it = 46080 | reward 53.3
# it = 47104 | reward 51.8
# it = 48128 | reward 143.3
# it = 49152 | reward 218.8
# it = 50176 | reward 85.7
# it = 51200 | reward 49.8
# it = 52224 | reward 48.4
# it = 53248 | reward 135.7
# it = 54272 | reward 319.4
# it = 55296 | reward 221.9
# it = 56320 | reward 167.5
# it = 57344 | reward 97.5
# it = 58368 | reward 48.3
# it = 59392 | reward 69.6
# it = 60416 | reward 52.5
# it = 61440 | reward 47.6
# it = 62464 | reward 194.4
# it = 63488 | reward 153.2
# it = 64512 | reward 307.3
# it = 65536 | reward 283.7
# it = 66560 | reward 280.7
# it = 67584 | reward 148.6
# it = 68608 | reward 280.4
# it = 69632 | reward 113.7
# it = 70656 | reward 49.7
# it = 71680 | reward 275.1
# it = 72704 | reward 41.3
# it = 73728 | reward 49.1
# it = 74752 | reward 81.9
# it = 75776 | reward 49.6
# it = 76800 | reward 51.7
# it = 77824 | reward 55.4
# it = 78848 | reward 58.9
# it = 79872 | reward 112.4
# it = 80896 | reward 82.2
# it = 81920 | reward 59.8
# it = 82944 | reward 220.7
# it = 83968 | reward 336.0
# it = 84992 | reward 276.7
# it = 86016 | reward 98.8
# it = 87040 | reward 48.4
# it = 88064 | reward 283.7
# it = 89088 | reward 66.1
# it = 90112 | reward 239.7
# it = 91136 | reward 152.6
# it = 92160 | reward 268.8
# it = 93184 | reward 305.9
# it = 94208 | reward 182.0
# it = 95232 | reward 59.2
# it = 96256 | reward 51.4
# it = 97280 | reward 60.2
# it = 98304 | reward 310.3
# it = 99328 | reward 168.5
# it = 100352 | reward 360.9
# it = 101376 | reward 96.2
# it = 102400 | reward 140.8
# (101,)
# ======= run = 4 / 19 =========
# it = 1024 | reward 38.6
# it = 2048 | reward 50.9
# it = 3072 | reward 48.1
# it = 4096 | reward 39.0
# it = 5120 | reward 49.8
# it = 6144 | reward 44.7
# it = 7168 | reward 54.5
# it = 8192 | reward 42.7
# it = 9216 | reward 51.3
# it = 10240 | reward 155.1
# it = 11264 | reward 77.5
# it = 12288 | reward 117.8
# it = 13312 | reward 237.0
# it = 14336 | reward 83.7
# it = 15360 | reward 263.6
# it = 16384 | reward 48.7
# it = 17408 | reward 47.1
# it = 18432 | reward 56.9
# it = 19456 | reward 53.8
# it = 20480 | reward 273.9
# it = 21504 | reward 102.6
# it = 22528 | reward 143.5
# it = 23552 | reward 58.0
# it = 24576 | reward 51.3
# it = 25600 | reward 45.6
# it = 26624 | reward 97.2
# it = 27648 | reward 365.7
# it = 28672 | reward 48.4
# it = 29696 | reward 209.8
# it = 30720 | reward 50.5
# it = 31744 | reward 44.8
# it = 32768 | reward 53.0
# it = 33792 | reward 41.8
# it = 34816 | reward 318.3
# it = 35840 | reward 240.4
# it = 36864 | reward 50.6
# it = 37888 | reward 48.3
# it = 38912 | reward 187.8
# it = 39936 | reward 59.3
# it = 40960 | reward 197.0
# it = 41984 | reward 141.9
# it = 43008 | reward 152.9
# it = 44032 | reward 182.3
# it = 45056 | reward 57.4
# it = 46080 | reward 242.6
# it = 47104 | reward 63.2
# it = 48128 | reward 44.1
# it = 49152 | reward 53.7
# it = 50176 | reward 58.8
# it = 51200 | reward 144.1
# it = 52224 | reward 57.7
# it = 53248 | reward 110.4
# it = 54272 | reward 238.1
# it = 55296 | reward 190.9
# it = 56320 | reward 186.9
# it = 57344 | reward 64.0
# it = 58368 | reward 43.7
# it = 59392 | reward 68.4
# it = 60416 | reward 136.4
# it = 61440 | reward 156.3
# it = 62464 | reward 270.4
# it = 63488 | reward 102.3
# it = 64512 | reward 48.9
# it = 65536 | reward 86.1
# it = 66560 | reward 215.7
# it = 67584 | reward 89.9
# it = 68608 | reward 46.8
# it = 69632 | reward 64.7
# it = 70656 | reward 81.6
# it = 71680 | reward 69.1
# it = 72704 | reward 75.5
# it = 73728 | reward 49.2
# it = 74752 | reward 69.1
# it = 75776 | reward 46.3
# it = 76800 | reward 73.0
# it = 77824 | reward 41.4
# it = 78848 | reward 55.2
# it = 79872 | reward 102.3
# it = 80896 | reward 109.2
# it = 81920 | reward 248.8
# it = 82944 | reward 101.0
# it = 83968 | reward 59.6
# it = 84992 | reward 169.8
# it = 86016 | reward 44.9
# it = 87040 | reward 57.5
# it = 88064 | reward 68.7
# it = 89088 | reward 102.8
# it = 90112 | reward 76.9
# it = 91136 | reward 44.8
# it = 92160 | reward 224.9
# it = 93184 | reward 265.0
# it = 94208 | reward 228.0
# it = 95232 | reward 320.5
# it = 96256 | reward 318.3
# it = 97280 | reward 191.8
# it = 98304 | reward 287.7
# it = 99328 | reward 55.8
# it = 100352 | reward 167.2
# it = 101376 | reward 363.4
# it = 102400 | reward 91.1
# (101,)
# ======= run = 5 / 19 =========
# it = 1024 | reward 32.9
# it = 2048 | reward 29.7
# it = 3072 | reward 48.5
# it = 4096 | reward 38.3
# it = 5120 | reward 34.2
# it = 6144 | reward 43.2
# it = 7168 | reward 46.5
# it = 8192 | reward 40.2
# it = 9216 | reward 77.2
# it = 10240 | reward 39.2
# it = 11264 | reward 148.1
# it = 12288 | reward 51.3
# it = 13312 | reward 49.6
# it = 14336 | reward 150.4
# it = 15360 | reward 55.8
# it = 16384 | reward 94.6
# it = 17408 | reward 62.7
# it = 18432 | reward 189.1
# it = 19456 | reward 127.0
# it = 20480 | reward 98.6
# it = 21504 | reward 110.4
# it = 22528 | reward 268.4
# it = 23552 | reward 97.8
# it = 24576 | reward 58.1
# it = 25600 | reward 107.4
# it = 26624 | reward 272.5
# it = 27648 | reward 228.1
# it = 28672 | reward 329.2
# it = 29696 | reward 412.8
# it = 30720 | reward 52.2
# it = 31744 | reward 59.9
# it = 32768 | reward 42.1
# it = 33792 | reward 147.3
# it = 34816 | reward 48.2
# it = 35840 | reward 62.9
# it = 36864 | reward 192.0
# it = 37888 | reward 58.4
# it = 38912 | reward 58.4
# it = 39936 | reward 233.3
# it = 40960 | reward 48.0
# it = 41984 | reward 42.6
# it = 43008 | reward 154.6
# it = 44032 | reward 266.9
# it = 45056 | reward 195.7
# it = 46080 | reward 181.2
# it = 47104 | reward 188.3
# it = 48128 | reward 274.9
# it = 49152 | reward 45.7
# it = 50176 | reward 54.7
# it = 51200 | reward 46.7
# it = 52224 | reward 79.0
# it = 53248 | reward 54.0
# it = 54272 | reward 106.6
# it = 55296 | reward 44.0
# it = 56320 | reward 48.1
# it = 57344 | reward 142.7
# it = 58368 | reward 41.4
# it = 59392 | reward 49.7
# it = 60416 | reward 42.8
# it = 61440 | reward 56.4
# it = 62464 | reward 272.8
# it = 63488 | reward 415.4
# it = 64512 | reward 285.4
# it = 65536 | reward 190.2
# it = 66560 | reward 143.0
# it = 67584 | reward 182.5
# it = 68608 | reward 55.2
# it = 69632 | reward 60.8
# it = 70656 | reward 92.2
# it = 71680 | reward 272.0
# it = 72704 | reward 44.8
# it = 73728 | reward 47.6
# it = 74752 | reward 48.8
# it = 75776 | reward 52.9
# it = 76800 | reward 47.8
# it = 77824 | reward 57.6
# it = 78848 | reward 74.3
# it = 79872 | reward 85.5
# it = 80896 | reward 91.4
# it = 81920 | reward 217.9
# it = 82944 | reward 46.6
# it = 83968 | reward 61.8
# it = 84992 | reward 51.0
# it = 86016 | reward 56.0
# it = 87040 | reward 182.8
# it = 88064 | reward 49.1
# it = 89088 | reward 191.4
# it = 90112 | reward 44.3
# it = 91136 | reward 64.5
# it = 92160 | reward 99.4
# it = 93184 | reward 146.4
# it = 94208 | reward 100.3
# it = 95232 | reward 323.9
# it = 96256 | reward 185.2
# it = 97280 | reward 253.4
# it = 98304 | reward 180.1
# it = 99328 | reward 229.0
# it = 100352 | reward 192.5
# it = 101376 | reward 331.2
# it = 102400 | reward 188.1
# (101,)
# ======= run = 6 / 19 =========
# it = 1024 | reward 35.0
# it = 2048 | reward 44.8
# it = 3072 | reward 42.3
# it = 4096 | reward 87.8
# it = 5120 | reward 40.1
# it = 6144 | reward 51.1
# it = 7168 | reward 138.2
# it = 8192 | reward 52.5
# it = 9216 | reward 47.4
# it = 10240 | reward 61.5
# it = 11264 | reward 147.8
# it = 12288 | reward 45.1
# it = 13312 | reward 47.3
# it = 14336 | reward 50.6
# it = 15360 | reward 45.4
# it = 16384 | reward 137.9
# it = 17408 | reward 117.9
# it = 18432 | reward 38.6
# it = 19456 | reward 48.5
# it = 20480 | reward 45.5
# it = 21504 | reward 136.5
# it = 22528 | reward 62.5
# it = 23552 | reward 262.8
# it = 24576 | reward 52.4
# it = 25600 | reward 138.5
# it = 26624 | reward 96.2
# it = 27648 | reward 81.4
# it = 28672 | reward 84.2
# it = 29696 | reward 61.6
# it = 30720 | reward 55.6
# it = 31744 | reward 184.8
# it = 32768 | reward 107.2
# it = 33792 | reward 46.0
# it = 34816 | reward 151.7
# it = 35840 | reward 243.9
# it = 36864 | reward 334.7
# it = 37888 | reward 54.6
# it = 38912 | reward 204.8
# it = 39936 | reward 176.8
# it = 40960 | reward 47.6
# it = 41984 | reward 56.0
# it = 43008 | reward 42.4
# it = 44032 | reward 187.0
# it = 45056 | reward 120.9
# it = 46080 | reward 72.1
# it = 47104 | reward 60.9
# it = 48128 | reward 196.4
# it = 49152 | reward 58.0
# it = 50176 | reward 115.6
# it = 51200 | reward 146.6
# it = 52224 | reward 62.8
# it = 53248 | reward 110.3
# it = 54272 | reward 46.7
# it = 55296 | reward 46.3
# it = 56320 | reward 47.0
# it = 57344 | reward 53.6
# it = 58368 | reward 78.8
# it = 59392 | reward 50.7
# it = 60416 | reward 201.8
# it = 61440 | reward 70.4
# it = 62464 | reward 47.0
# it = 63488 | reward 149.8
# it = 64512 | reward 59.2
# it = 65536 | reward 49.9
# it = 66560 | reward 271.3
# it = 67584 | reward 271.6
# it = 68608 | reward 54.0
# it = 69632 | reward 51.1
# it = 70656 | reward 51.2
# it = 71680 | reward 225.3
# it = 72704 | reward 135.0
# it = 73728 | reward 240.0
# it = 74752 | reward 52.3
# it = 75776 | reward 287.6
# it = 76800 | reward 357.3
# it = 77824 | reward 211.1
# it = 78848 | reward 192.7
# it = 79872 | reward 50.1
# it = 80896 | reward 101.4
# it = 81920 | reward 65.5
# it = 82944 | reward 181.4
# it = 83968 | reward 181.4
# it = 84992 | reward 282.2
# it = 86016 | reward 63.3
# it = 87040 | reward 187.5
# it = 88064 | reward 197.9
# it = 89088 | reward 46.3
# it = 90112 | reward 47.3
# it = 91136 | reward 49.2
# it = 92160 | reward 47.8
# it = 93184 | reward 53.3
# it = 94208 | reward 59.6
# it = 95232 | reward 104.3
# it = 96256 | reward 247.1
# it = 97280 | reward 48.0
# it = 98304 | reward 76.8
# it = 99328 | reward 45.9
# it = 100352 | reward 52.7
# it = 101376 | reward 54.5
# it = 102400 | reward 50.1
# (101,)
# ======= run = 7 / 19 =========
# it = 1024 | reward 41.2
# it = 2048 | reward 32.2
# it = 3072 | reward 38.3
# it = 4096 | reward 33.8
# it = 5120 | reward 45.4
# it = 6144 | reward 36.9
# it = 7168 | reward 35.4
# it = 8192 | reward 34.0
# it = 9216 | reward 31.5
# it = 10240 | reward 41.5
# it = 11264 | reward 37.2
# it = 12288 | reward 38.8
# it = 13312 | reward 37.1
# it = 14336 | reward 39.0
# it = 15360 | reward 46.9
# it = 16384 | reward 34.1
# it = 17408 | reward 44.0
# it = 18432 | reward 47.7
# it = 19456 | reward 48.0
# it = 20480 | reward 45.5
# it = 21504 | reward 66.3
# it = 22528 | reward 52.0
# it = 23552 | reward 49.8
# it = 24576 | reward 69.9
# it = 25600 | reward 42.2
# it = 26624 | reward 47.8
# it = 27648 | reward 76.5
# it = 28672 | reward 40.3
# it = 29696 | reward 81.8
# it = 30720 | reward 67.6
# it = 31744 | reward 45.5
# it = 32768 | reward 37.7
# it = 33792 | reward 39.6
# it = 34816 | reward 52.5
# it = 35840 | reward 130.8
# it = 36864 | reward 75.6
# it = 37888 | reward 43.3
# it = 38912 | reward 48.5
# it = 39936 | reward 48.1
# it = 40960 | reward 149.2
# it = 41984 | reward 45.0
# it = 43008 | reward 243.0
# it = 44032 | reward 73.0
# it = 45056 | reward 41.4
# it = 46080 | reward 264.5
# it = 47104 | reward 45.4
# it = 48128 | reward 193.3
# it = 49152 | reward 235.7
# it = 50176 | reward 59.4
# it = 51200 | reward 43.3
# it = 52224 | reward 50.6
# it = 53248 | reward 98.9
# it = 54272 | reward 51.2
# it = 55296 | reward 319.2
# it = 56320 | reward 65.1
# it = 57344 | reward 49.9
# it = 58368 | reward 50.5
# it = 59392 | reward 40.3
# it = 60416 | reward 38.5
# it = 61440 | reward 69.3
# it = 62464 | reward 239.5
# it = 63488 | reward 134.1
# it = 64512 | reward 224.0
# it = 65536 | reward 48.1
# it = 66560 | reward 49.9
# it = 67584 | reward 50.3
# it = 68608 | reward 62.8
# it = 69632 | reward 62.7
# it = 70656 | reward 58.3
# it = 71680 | reward 49.0
# it = 72704 | reward 46.6
# it = 73728 | reward 57.5
# it = 74752 | reward 51.7
# it = 75776 | reward 46.0
# it = 76800 | reward 54.8
# it = 77824 | reward 48.2
# it = 78848 | reward 39.4
# it = 79872 | reward 43.0
# it = 80896 | reward 191.7
# it = 81920 | reward 60.2
# it = 82944 | reward 96.7
# it = 83968 | reward 66.3
# it = 84992 | reward 50.3
# it = 86016 | reward 185.8
# it = 87040 | reward 268.8
# it = 88064 | reward 57.9
# it = 89088 | reward 51.8
# it = 90112 | reward 154.8
# it = 91136 | reward 49.4
# it = 92160 | reward 90.0
# it = 93184 | reward 51.1
# it = 94208 | reward 59.1
# it = 95232 | reward 42.2
# it = 96256 | reward 80.6
# it = 97280 | reward 226.4
# it = 98304 | reward 227.9
# it = 99328 | reward 235.5
# it = 100352 | reward 233.1
# it = 101376 | reward 54.0
# it = 102400 | reward 45.2
# (101,)
# ======= run = 8 / 19 =========
# it = 1024 | reward 34.5
# it = 2048 | reward 39.8
# it = 3072 | reward 41.1
# it = 4096 | reward 38.0
# it = 5120 | reward 35.2
# it = 6144 | reward 36.8
# it = 7168 | reward 39.4
# it = 8192 | reward 39.5
# it = 9216 | reward 41.7
# it = 10240 | reward 54.7
# it = 11264 | reward 37.7
# it = 12288 | reward 67.9
# it = 13312 | reward 73.3
# it = 14336 | reward 48.8
# it = 15360 | reward 49.5
# it = 16384 | reward 43.7
# it = 17408 | reward 49.8
# it = 18432 | reward 56.9
# it = 19456 | reward 67.3
# it = 20480 | reward 51.8
# it = 21504 | reward 104.3
# it = 22528 | reward 48.0
# it = 23552 | reward 57.5
# it = 24576 | reward 48.1
# it = 25600 | reward 52.0
# it = 26624 | reward 138.0
# it = 27648 | reward 155.6
# it = 28672 | reward 46.5
# it = 29696 | reward 127.2
# it = 30720 | reward 229.8
# it = 31744 | reward 97.9
# it = 32768 | reward 242.1
# it = 33792 | reward 149.9
# it = 34816 | reward 231.1
# it = 35840 | reward 186.6
# it = 36864 | reward 283.1
# it = 37888 | reward 278.4
# it = 38912 | reward 185.1
# it = 39936 | reward 324.3
# it = 40960 | reward 54.7
# it = 41984 | reward 98.0
# it = 43008 | reward 71.3
# it = 44032 | reward 54.0
# it = 45056 | reward 57.8
# it = 46080 | reward 273.6
# it = 47104 | reward 199.5
# it = 48128 | reward 185.6
# it = 49152 | reward 117.5
# it = 50176 | reward 57.2
# it = 51200 | reward 57.0
# it = 52224 | reward 90.0
# it = 53248 | reward 54.6
# it = 54272 | reward 149.4
# it = 55296 | reward 236.2
# it = 56320 | reward 46.1
# it = 57344 | reward 271.9
# it = 58368 | reward 139.5
# it = 59392 | reward 286.8
# it = 60416 | reward 50.6
# it = 61440 | reward 52.3
# it = 62464 | reward 55.2
# it = 63488 | reward 44.7
# it = 64512 | reward 49.3
# it = 65536 | reward 56.3
# it = 66560 | reward 76.3
# it = 67584 | reward 113.3
# it = 68608 | reward 236.3
# it = 69632 | reward 74.0
# it = 70656 | reward 65.9
# it = 71680 | reward 183.7
# it = 72704 | reward 52.0
# it = 73728 | reward 182.3
# it = 74752 | reward 44.3
# it = 75776 | reward 89.3
# it = 76800 | reward 191.6
# it = 77824 | reward 317.1
# it = 78848 | reward 49.0
# it = 79872 | reward 119.3
# it = 80896 | reward 311.9
# it = 81920 | reward 224.8
# it = 82944 | reward 268.9
# it = 83968 | reward 328.6
# it = 84992 | reward 141.2
# it = 86016 | reward 182.3
# it = 87040 | reward 134.1
# it = 88064 | reward 268.9
# it = 89088 | reward 275.4
# it = 90112 | reward 312.0
# it = 91136 | reward 42.8
# it = 92160 | reward 135.2
# it = 93184 | reward 226.9
# it = 94208 | reward 234.9
# it = 95232 | reward 238.6
# it = 96256 | reward 186.7
# it = 97280 | reward 257.4
# it = 98304 | reward 204.5
# it = 99328 | reward 53.0
# it = 100352 | reward 46.6
# it = 101376 | reward 51.2
# it = 102400 | reward 49.4
# (101,)
# ======= run = 9 / 19 =========
# it = 1024 | reward 30.2
# it = 2048 | reward 49.1
# it = 3072 | reward 62.1
# it = 4096 | reward 56.7
# it = 5120 | reward 61.5
# it = 6144 | reward 59.5
# it = 7168 | reward 67.0
# it = 8192 | reward 50.2
# it = 9216 | reward 161.3
# it = 10240 | reward 46.3
# it = 11264 | reward 46.0
# it = 12288 | reward 59.7
# it = 13312 | reward 61.0
# it = 14336 | reward 114.8
# it = 15360 | reward 168.5
# it = 16384 | reward 100.2
# it = 17408 | reward 58.8
# it = 18432 | reward 48.7
# it = 19456 | reward 61.8
# it = 20480 | reward 67.2
# it = 21504 | reward 43.7
# it = 22528 | reward 52.6
# it = 23552 | reward 55.2
# it = 24576 | reward 56.8
# it = 25600 | reward 214.9
# it = 26624 | reward 52.9
# it = 27648 | reward 78.4
# it = 28672 | reward 49.4
# it = 29696 | reward 48.7
# it = 30720 | reward 40.8
# it = 31744 | reward 56.8
# it = 32768 | reward 80.1
# it = 33792 | reward 52.9
# it = 34816 | reward 59.9
# it = 35840 | reward 51.3
# it = 36864 | reward 44.2
# it = 37888 | reward 53.7
# it = 38912 | reward 283.5
# it = 39936 | reward 141.3
# it = 40960 | reward 63.5
# it = 41984 | reward 50.2
# it = 43008 | reward 58.6
# it = 44032 | reward 261.2
# it = 45056 | reward 127.6
# it = 46080 | reward 202.9
# it = 47104 | reward 54.8
# it = 48128 | reward 44.7
# it = 49152 | reward 70.8
# it = 50176 | reward 93.5
# it = 51200 | reward 43.5
# it = 52224 | reward 276.3
# it = 53248 | reward 53.2
# it = 54272 | reward 65.3
# it = 55296 | reward 67.1
# it = 56320 | reward 56.9
# it = 57344 | reward 208.9
# it = 58368 | reward 164.5
# it = 59392 | reward 286.3
# it = 60416 | reward 92.3
# it = 61440 | reward 52.5
# it = 62464 | reward 171.1
# it = 63488 | reward 41.6
# it = 64512 | reward 82.3
# it = 65536 | reward 68.6
# it = 66560 | reward 209.7
# it = 67584 | reward 104.2
# it = 68608 | reward 180.2
# it = 69632 | reward 47.2
# it = 70656 | reward 53.1
# it = 71680 | reward 131.1
# it = 72704 | reward 57.1
# it = 73728 | reward 54.5
# it = 74752 | reward 52.5
# it = 75776 | reward 53.7
# it = 76800 | reward 48.9
# it = 77824 | reward 38.4
# it = 78848 | reward 56.3
# it = 79872 | reward 44.7
# it = 80896 | reward 51.6
# it = 81920 | reward 45.1
# it = 82944 | reward 45.8
# it = 83968 | reward 52.2
# it = 84992 | reward 114.3
# it = 86016 | reward 54.2
# it = 87040 | reward 41.4
# it = 88064 | reward 49.1
# it = 89088 | reward 37.6
# it = 90112 | reward 47.5
# it = 91136 | reward 43.3
# it = 92160 | reward 51.9
# it = 93184 | reward 48.4
# it = 94208 | reward 48.3
# it = 95232 | reward 168.2
# it = 96256 | reward 68.3
# it = 97280 | reward 55.1
# it = 98304 | reward 57.6
# it = 99328 | reward 53.3
# it = 100352 | reward 68.1
# it = 101376 | reward 96.5
# it = 102400 | reward 132.0
# (101,)
# ======= run = 10 / 19 =========
# it = 1024 | reward 33.4
# it = 2048 | reward 38.3
# it = 3072 | reward 51.9
# it = 4096 | reward 48.6
# it = 5120 | reward 39.6
# it = 6144 | reward 46.6
# it = 7168 | reward 65.4
# it = 8192 | reward 51.3
# it = 9216 | reward 208.7
# it = 10240 | reward 41.8
# it = 11264 | reward 92.3
# it = 12288 | reward 44.7
# it = 13312 | reward 58.6
# it = 14336 | reward 125.0
# it = 15360 | reward 50.9
# it = 16384 | reward 287.6
# it = 17408 | reward 40.2
# it = 18432 | reward 51.6
# it = 19456 | reward 84.6
# it = 20480 | reward 54.3
# it = 21504 | reward 38.5
# it = 22528 | reward 43.9
# it = 23552 | reward 293.6
# it = 24576 | reward 96.2
# it = 25600 | reward 245.6
# it = 26624 | reward 108.8
# it = 27648 | reward 181.0
# it = 28672 | reward 236.7
# it = 29696 | reward 152.8
# it = 30720 | reward 166.4
# it = 31744 | reward 62.2
# it = 32768 | reward 198.8
# it = 33792 | reward 45.1
# it = 34816 | reward 77.4
# it = 35840 | reward 151.2
# it = 36864 | reward 43.7
# it = 37888 | reward 51.9
# it = 38912 | reward 45.3
# it = 39936 | reward 61.5
# it = 40960 | reward 50.6
# it = 41984 | reward 254.5
# it = 43008 | reward 108.3
# it = 44032 | reward 54.5
# it = 45056 | reward 109.5
# it = 46080 | reward 228.7
# it = 47104 | reward 397.1
# it = 48128 | reward 50.4
# it = 49152 | reward 45.3
# it = 50176 | reward 40.3
# it = 51200 | reward 105.4
# it = 52224 | reward 169.7
# it = 53248 | reward 178.3
# it = 54272 | reward 251.6
# it = 55296 | reward 136.4
# it = 56320 | reward 192.3
# it = 57344 | reward 61.9
# it = 58368 | reward 258.1
# it = 59392 | reward 105.8
# it = 60416 | reward 176.1
# it = 61440 | reward 227.2
# it = 62464 | reward 74.6
# it = 63488 | reward 187.0
# it = 64512 | reward 60.1
# it = 65536 | reward 43.5
# it = 66560 | reward 92.8
# it = 67584 | reward 47.6
# it = 68608 | reward 226.6
# it = 69632 | reward 156.6
# it = 70656 | reward 50.2
# it = 71680 | reward 54.5
# it = 72704 | reward 61.8
# it = 73728 | reward 60.2
# it = 74752 | reward 103.2
# it = 75776 | reward 45.2
# it = 76800 | reward 228.3
# it = 77824 | reward 51.2
# it = 78848 | reward 90.5
# it = 79872 | reward 54.7
# it = 80896 | reward 59.5
# it = 81920 | reward 112.5
# it = 82944 | reward 230.5
# it = 83968 | reward 307.8
# it = 84992 | reward 161.6
# it = 86016 | reward 271.9
# it = 87040 | reward 100.5
# it = 88064 | reward 86.5
# it = 89088 | reward 66.6
# it = 90112 | reward 118.0
# it = 91136 | reward 113.5
# it = 92160 | reward 50.7
# it = 93184 | reward 101.9
# it = 94208 | reward 127.0
# it = 95232 | reward 75.0
# it = 96256 | reward 110.8
# it = 97280 | reward 225.8
# it = 98304 | reward 55.3
# it = 99328 | reward 127.2
# it = 100352 | reward 191.9
# it = 101376 | reward 362.3
# it = 102400 | reward 115.4
# (101,)
# ======= run = 11 / 19 =========
# it = 1024 | reward 36.6
# it = 2048 | reward 38.6
# it = 3072 | reward 39.3
# it = 4096 | reward 41.4
# it = 5120 | reward 46.3
# it = 6144 | reward 41.2
# it = 7168 | reward 36.1
# it = 8192 | reward 47.2
# it = 9216 | reward 31.7
# it = 10240 | reward 31.2
# it = 11264 | reward 37.8
# it = 12288 | reward 38.6
# it = 13312 | reward 41.5
# it = 14336 | reward 33.9
# it = 15360 | reward 37.6
# it = 16384 | reward 41.0
# it = 17408 | reward 43.7
# it = 18432 | reward 34.0
# it = 19456 | reward 48.3
# it = 20480 | reward 40.4
# it = 21504 | reward 38.8
# it = 22528 | reward 39.8
# it = 23552 | reward 37.0
# it = 24576 | reward 37.5
# it = 25600 | reward 37.9
# it = 26624 | reward 37.5
# it = 27648 | reward 38.7
# it = 28672 | reward 43.6
# it = 29696 | reward 37.8
# it = 30720 | reward 44.0
# it = 31744 | reward 36.0
# it = 32768 | reward 46.2
# it = 33792 | reward 43.3
# it = 34816 | reward 38.0
# it = 35840 | reward 40.5
# it = 36864 | reward 36.8
# it = 37888 | reward 41.9
# it = 38912 | reward 30.7
# it = 39936 | reward 34.1
# it = 40960 | reward 34.4
# it = 41984 | reward 39.1
# it = 43008 | reward 35.4
# it = 44032 | reward 43.8
# it = 45056 | reward 34.8
# it = 46080 | reward 37.1
# it = 47104 | reward 37.1
# it = 48128 | reward 38.8
# it = 49152 | reward 41.0
# it = 50176 | reward 38.6
# it = 51200 | reward 35.9
# it = 52224 | reward 37.7
# it = 53248 | reward 36.9
# it = 54272 | reward 34.0
# it = 55296 | reward 38.1
# it = 56320 | reward 33.2
# it = 57344 | reward 35.3
# it = 58368 | reward 38.0
# it = 59392 | reward 33.5
# it = 60416 | reward 43.1
# it = 61440 | reward 36.1
# it = 62464 | reward 47.2
# it = 63488 | reward 32.3
# it = 64512 | reward 45.5
# it = 65536 | reward 34.2
# it = 66560 | reward 35.3
# it = 67584 | reward 33.2
# it = 68608 | reward 40.2
# it = 69632 | reward 41.7
# it = 70656 | reward 40.3
# it = 71680 | reward 36.6
# it = 72704 | reward 39.1
# it = 73728 | reward 39.3
# it = 74752 | reward 47.7
# it = 75776 | reward 43.7
# it = 76800 | reward 39.3
# it = 77824 | reward 34.4
# it = 78848 | reward 33.2
# it = 79872 | reward 34.3
# it = 80896 | reward 30.5
# it = 81920 | reward 40.3
# it = 82944 | reward 36.2
# it = 83968 | reward 31.7
# it = 84992 | reward 38.3
# it = 86016 | reward 41.2
# it = 87040 | reward 40.8
# it = 88064 | reward 41.2
# it = 89088 | reward 35.6
# it = 90112 | reward 39.0
# it = 91136 | reward 34.1
# it = 92160 | reward 36.9
# it = 93184 | reward 39.7
# it = 94208 | reward 42.2
# it = 95232 | reward 36.2
# it = 96256 | reward 35.0
# it = 97280 | reward 34.7
# it = 98304 | reward 35.8
# it = 99328 | reward 34.6
# it = 100352 | reward 34.8
# it = 101376 | reward 41.3
# it = 102400 | reward 34.2
# (101,)
# ======= run = 12 / 19 =========
# it = 1024 | reward 33.2
# it = 2048 | reward 43.2
# it = 3072 | reward 54.0
# it = 4096 | reward 53.8
# it = 5120 | reward 65.2
# it = 6144 | reward 78.8
# it = 7168 | reward 52.6
# it = 8192 | reward 54.0
# it = 9216 | reward 57.9
# it = 10240 | reward 51.2
# it = 11264 | reward 41.6
# it = 12288 | reward 57.4
# it = 13312 | reward 118.0
# it = 14336 | reward 40.4
# it = 15360 | reward 45.1
# it = 16384 | reward 52.4
# it = 17408 | reward 44.5
# it = 18432 | reward 189.9
# it = 19456 | reward 50.3
# it = 20480 | reward 124.8
# it = 21504 | reward 42.9
# it = 22528 | reward 236.0
# it = 23552 | reward 53.7
# it = 24576 | reward 184.0
# it = 25600 | reward 49.9
# it = 26624 | reward 102.3
# it = 27648 | reward 53.2
# it = 28672 | reward 44.9
# it = 29696 | reward 115.0
# it = 30720 | reward 67.7
# it = 31744 | reward 50.4
# it = 32768 | reward 100.3
# it = 33792 | reward 281.8
# it = 34816 | reward 55.0
# it = 35840 | reward 280.1
# it = 36864 | reward 51.2
# it = 37888 | reward 57.1
# it = 38912 | reward 54.7
# it = 39936 | reward 59.3
# it = 40960 | reward 133.9
# it = 41984 | reward 53.7
# it = 43008 | reward 54.7
# it = 44032 | reward 110.6
# it = 45056 | reward 44.1
# it = 46080 | reward 42.8
# it = 47104 | reward 48.0
# it = 48128 | reward 143.4
# it = 49152 | reward 262.5
# it = 50176 | reward 216.1
# it = 51200 | reward 191.9
# it = 52224 | reward 145.9
# it = 53248 | reward 272.7
# it = 54272 | reward 230.6
# it = 55296 | reward 317.8
# it = 56320 | reward 229.8
# it = 57344 | reward 210.0
# it = 58368 | reward 232.8
# it = 59392 | reward 330.2
# it = 60416 | reward 113.1
# it = 61440 | reward 182.8
# it = 62464 | reward 57.4
# it = 63488 | reward 274.6
# it = 64512 | reward 236.3
# it = 65536 | reward 314.6
# it = 66560 | reward 94.1
# it = 67584 | reward 213.4
# it = 68608 | reward 47.0
# it = 69632 | reward 57.8
# it = 70656 | reward 47.9
# it = 71680 | reward 113.9
# it = 72704 | reward 148.4
# it = 73728 | reward 80.0
# it = 74752 | reward 205.8
# it = 75776 | reward 163.0
# it = 76800 | reward 236.6
# it = 77824 | reward 98.0
# it = 78848 | reward 56.1
# it = 79872 | reward 128.8
# it = 80896 | reward 64.7
# it = 81920 | reward 234.3
# it = 82944 | reward 101.9
# it = 83968 | reward 63.9
# it = 84992 | reward 67.3
# it = 86016 | reward 37.3
# it = 87040 | reward 51.2
# it = 88064 | reward 315.1
# it = 89088 | reward 85.4
# it = 90112 | reward 49.1
# it = 91136 | reward 279.9
# it = 92160 | reward 188.7
# it = 93184 | reward 52.4
# it = 94208 | reward 56.6
# it = 95232 | reward 54.1
# it = 96256 | reward 191.4
# it = 97280 | reward 64.6
# it = 98304 | reward 189.3
# it = 99328 | reward 55.6
# it = 100352 | reward 56.7
# it = 101376 | reward 48.9
# it = 102400 | reward 111.7
# (101,)
# ======= run = 13 / 19 =========
# it = 1024 | reward 39.6
# it = 2048 | reward 58.3
# it = 3072 | reward 38.9
# it = 4096 | reward 42.1
# it = 5120 | reward 33.9
# it = 6144 | reward 41.4
# it = 7168 | reward 36.8
# it = 8192 | reward 36.7
# it = 9216 | reward 34.6
# it = 10240 | reward 55.0
# it = 11264 | reward 44.9
# it = 12288 | reward 46.8
# it = 13312 | reward 42.8
# it = 14336 | reward 38.8
# it = 15360 | reward 34.0
# it = 16384 | reward 34.6
# it = 17408 | reward 34.4
# it = 18432 | reward 36.6
# it = 19456 | reward 39.5
# it = 20480 | reward 37.7
# it = 21504 | reward 35.7
# it = 22528 | reward 42.0
# it = 23552 | reward 33.8
# it = 24576 | reward 39.1
# it = 25600 | reward 36.5
# it = 26624 | reward 36.5
# it = 27648 | reward 46.9
# it = 28672 | reward 51.7
# it = 29696 | reward 58.5
# it = 30720 | reward 62.6
# it = 31744 | reward 54.3
# it = 32768 | reward 95.1
# it = 33792 | reward 40.0
# it = 34816 | reward 126.0
# it = 35840 | reward 46.8
# it = 36864 | reward 250.0
# it = 37888 | reward 45.1
# it = 38912 | reward 44.5
# it = 39936 | reward 280.5
# it = 40960 | reward 41.1
# it = 41984 | reward 49.9
# it = 43008 | reward 40.6
# it = 44032 | reward 46.5
# it = 45056 | reward 47.0
# it = 46080 | reward 50.7
# it = 47104 | reward 50.6
# it = 48128 | reward 106.6
# it = 49152 | reward 41.2
# it = 50176 | reward 58.1
# it = 51200 | reward 330.4
# it = 52224 | reward 149.0
# it = 53248 | reward 37.6
# it = 54272 | reward 51.9
# it = 55296 | reward 45.7
# it = 56320 | reward 237.7
# it = 57344 | reward 37.6
# it = 58368 | reward 122.7
# it = 59392 | reward 115.0
# it = 60416 | reward 72.0
# it = 61440 | reward 186.8
# it = 62464 | reward 238.5
# it = 63488 | reward 50.6
# it = 64512 | reward 71.2
# it = 65536 | reward 51.3
# it = 66560 | reward 152.6
# it = 67584 | reward 87.8
# it = 68608 | reward 51.3
# it = 69632 | reward 186.6
# it = 70656 | reward 108.4
# it = 71680 | reward 198.7
# it = 72704 | reward 315.7
# it = 73728 | reward 54.7
# it = 74752 | reward 46.6
# it = 75776 | reward 42.9
# it = 76800 | reward 44.9
# it = 77824 | reward 46.8
# it = 78848 | reward 46.8
# it = 79872 | reward 458.8
# it = 80896 | reward 49.8
# it = 81920 | reward 180.7
# it = 82944 | reward 323.6
# it = 83968 | reward 50.0
# it = 84992 | reward 44.1
# it = 86016 | reward 40.2
# it = 87040 | reward 45.0
# it = 88064 | reward 42.1
# it = 89088 | reward 47.5
# it = 90112 | reward 92.8
# it = 91136 | reward 42.1
# it = 92160 | reward 43.8
# it = 93184 | reward 48.9
# it = 94208 | reward 58.3
# it = 95232 | reward 51.9
# it = 96256 | reward 47.3
# it = 97280 | reward 49.9
# it = 98304 | reward 40.8
# it = 99328 | reward 50.6
# it = 100352 | reward 109.9
# it = 101376 | reward 110.9
# it = 102400 | reward 222.7
# (101,)
# ======= run = 14 / 19 =========
# it = 1024 | reward 39.1
# it = 2048 | reward 40.2
# it = 3072 | reward 60.8
# it = 4096 | reward 55.6
# it = 5120 | reward 89.4
# it = 6144 | reward 91.9
# it = 7168 | reward 92.3
# it = 8192 | reward 217.9
# it = 9216 | reward 50.7
# it = 10240 | reward 42.6
# it = 11264 | reward 140.6
# it = 12288 | reward 144.8
# it = 13312 | reward 45.8
# it = 14336 | reward 78.2
# it = 15360 | reward 70.5
# it = 16384 | reward 46.1
# it = 17408 | reward 241.4
# it = 18432 | reward 53.5
# it = 19456 | reward 40.6
# it = 20480 | reward 135.5
# it = 21504 | reward 42.3
# it = 22528 | reward 114.4
# it = 23552 | reward 102.4
# it = 24576 | reward 80.0
# it = 25600 | reward 48.3
# it = 26624 | reward 262.8
# it = 27648 | reward 74.2
# it = 28672 | reward 138.7
# it = 29696 | reward 324.9
# it = 30720 | reward 184.6
# it = 31744 | reward 54.7
# it = 32768 | reward 47.2
# it = 33792 | reward 42.8
# it = 34816 | reward 52.4
# it = 35840 | reward 61.7
# it = 36864 | reward 109.5
# it = 37888 | reward 144.5
# it = 38912 | reward 179.7
# it = 39936 | reward 179.9
# it = 40960 | reward 59.1
# it = 41984 | reward 49.2
# it = 43008 | reward 44.9
# it = 44032 | reward 233.4
# it = 45056 | reward 203.8
# it = 46080 | reward 52.5
# it = 47104 | reward 111.9
# it = 48128 | reward 110.3
# it = 49152 | reward 106.0
# it = 50176 | reward 132.3
# it = 51200 | reward 45.9
# it = 52224 | reward 51.6
# it = 53248 | reward 142.5
# it = 54272 | reward 54.4
# it = 55296 | reward 51.4
# it = 56320 | reward 42.0
# it = 57344 | reward 38.9
# it = 58368 | reward 44.9
# it = 59392 | reward 55.2
# it = 60416 | reward 72.5
# it = 61440 | reward 54.8
# it = 62464 | reward 145.5
# it = 63488 | reward 52.7
# it = 64512 | reward 50.5
# it = 65536 | reward 183.4
# it = 66560 | reward 109.1
# it = 67584 | reward 148.6
# it = 68608 | reward 76.1
# it = 69632 | reward 160.5
# it = 70656 | reward 52.7
# it = 71680 | reward 42.5
# it = 72704 | reward 83.7
# it = 73728 | reward 233.6
# it = 74752 | reward 53.0
# it = 75776 | reward 181.1
# it = 76800 | reward 144.6
# it = 77824 | reward 202.8
# it = 78848 | reward 282.0
# it = 79872 | reward 104.5
# it = 80896 | reward 186.4
# it = 81920 | reward 283.0
# it = 82944 | reward 109.2
# it = 83968 | reward 68.7
# it = 84992 | reward 120.4
# it = 86016 | reward 65.8
# it = 87040 | reward 324.3
# it = 88064 | reward 107.0
# it = 89088 | reward 202.8
# it = 90112 | reward 181.7
# it = 91136 | reward 279.0
# it = 92160 | reward 225.4
# it = 93184 | reward 228.7
# it = 94208 | reward 335.5
# it = 95232 | reward 56.2
# it = 96256 | reward 62.0
# it = 97280 | reward 65.0
# it = 98304 | reward 50.4
# it = 99328 | reward 227.7
# it = 100352 | reward 51.8
# it = 101376 | reward 409.2
# it = 102400 | reward 231.6
# (101,)
# ======= run = 15 / 19 =========
# it = 1024 | reward 41.0
# it = 2048 | reward 35.6
# it = 3072 | reward 39.0
# it = 4096 | reward 43.8
# it = 5120 | reward 33.4
# it = 6144 | reward 35.5
# it = 7168 | reward 58.3
# it = 8192 | reward 40.9
# it = 9216 | reward 107.2
# it = 10240 | reward 49.3
# it = 11264 | reward 44.4
# it = 12288 | reward 60.2
# it = 13312 | reward 89.2
# it = 14336 | reward 52.7
# it = 15360 | reward 46.2
# it = 16384 | reward 109.2
# it = 17408 | reward 39.1
# it = 18432 | reward 197.3
# it = 19456 | reward 61.9
# it = 20480 | reward 45.0
# it = 21504 | reward 94.1
# it = 22528 | reward 73.5
# it = 23552 | reward 57.9
# it = 24576 | reward 60.8
# it = 25600 | reward 94.1
# it = 26624 | reward 151.5
# it = 27648 | reward 58.0
# it = 28672 | reward 152.1
# it = 29696 | reward 233.2
# it = 30720 | reward 104.2
# it = 31744 | reward 60.0
# it = 32768 | reward 42.3
# it = 33792 | reward 45.0
# it = 34816 | reward 47.3
# it = 35840 | reward 74.6
# it = 36864 | reward 202.0
# it = 37888 | reward 66.3
# it = 38912 | reward 233.1
# it = 39936 | reward 251.0
# it = 40960 | reward 316.2
# it = 41984 | reward 186.5
# it = 43008 | reward 207.3
# it = 44032 | reward 272.4
# it = 45056 | reward 85.2
# it = 46080 | reward 147.2
# it = 47104 | reward 155.3
# it = 48128 | reward 58.3
# it = 49152 | reward 51.6
# it = 50176 | reward 51.5
# it = 51200 | reward 53.0
# it = 52224 | reward 39.2
# it = 53248 | reward 52.9
# it = 54272 | reward 42.6
# it = 55296 | reward 53.9
# it = 56320 | reward 49.2
# it = 57344 | reward 52.2
# it = 58368 | reward 75.4
# it = 59392 | reward 365.2
# it = 60416 | reward 62.7
# it = 61440 | reward 108.3
# it = 62464 | reward 122.3
# it = 63488 | reward 226.3
# it = 64512 | reward 264.3
# it = 65536 | reward 231.5
# it = 66560 | reward 113.7
# it = 67584 | reward 415.3
# it = 68608 | reward 269.9
# it = 69632 | reward 273.6
# it = 70656 | reward 270.4
# it = 71680 | reward 66.8
# it = 72704 | reward 61.8
# it = 73728 | reward 70.5
# it = 74752 | reward 316.5
# it = 75776 | reward 60.5
# it = 76800 | reward 45.2
# it = 77824 | reward 41.4
# it = 78848 | reward 59.5
# it = 79872 | reward 47.4
# it = 80896 | reward 45.7
# it = 81920 | reward 61.1
# it = 82944 | reward 109.2
# it = 83968 | reward 102.0
# it = 84992 | reward 269.1
# it = 86016 | reward 101.5
# it = 87040 | reward 193.2
# it = 88064 | reward 103.5
# it = 89088 | reward 42.8
# it = 90112 | reward 60.6
# it = 91136 | reward 172.8
# it = 92160 | reward 151.1
# it = 93184 | reward 155.9
# it = 94208 | reward 130.8
# it = 95232 | reward 86.3
# it = 96256 | reward 133.4
# it = 97280 | reward 54.7
# it = 98304 | reward 184.5
# it = 99328 | reward 415.4
# it = 100352 | reward 270.9
# it = 101376 | reward 78.8
# it = 102400 | reward 206.6
# (101,)
# ======= run = 16 / 19 =========
# it = 1024 | reward 34.4
# it = 2048 | reward 45.7
# it = 3072 | reward 39.3
# it = 4096 | reward 38.0
# it = 5120 | reward 39.1
# it = 6144 | reward 43.6
# it = 7168 | reward 37.4
# it = 8192 | reward 38.1
# it = 9216 | reward 36.6
# it = 10240 | reward 34.2
# it = 11264 | reward 36.2
# it = 12288 | reward 38.6
# it = 13312 | reward 39.0
# it = 14336 | reward 38.5
# it = 15360 | reward 42.0
# it = 16384 | reward 38.8
# it = 17408 | reward 32.1
# it = 18432 | reward 34.6
# it = 19456 | reward 37.9
# it = 20480 | reward 42.0
# it = 21504 | reward 38.1
# it = 22528 | reward 62.2
# it = 23552 | reward 53.4
# it = 24576 | reward 41.7
# it = 25600 | reward 47.8
# it = 26624 | reward 63.2
# it = 27648 | reward 54.3
# it = 28672 | reward 53.4
# it = 29696 | reward 51.2
# it = 30720 | reward 69.2
# it = 31744 | reward 57.2
# it = 32768 | reward 67.0
# it = 33792 | reward 46.4
# it = 34816 | reward 169.8
# it = 35840 | reward 40.1
# it = 36864 | reward 40.8
# it = 37888 | reward 49.8
# it = 38912 | reward 48.8
# it = 39936 | reward 49.3
# it = 40960 | reward 81.0
# it = 41984 | reward 184.1
# it = 43008 | reward 58.9
# it = 44032 | reward 181.1
# it = 45056 | reward 57.9
# it = 46080 | reward 41.3
# it = 47104 | reward 42.0
# it = 48128 | reward 44.7
# it = 49152 | reward 41.8
# it = 50176 | reward 51.4
# it = 51200 | reward 53.7
# it = 52224 | reward 47.2
# it = 53248 | reward 45.7
# it = 54272 | reward 48.1
# it = 55296 | reward 45.0
# it = 56320 | reward 50.9
# it = 57344 | reward 35.4
# it = 58368 | reward 47.8
# it = 59392 | reward 42.2
# it = 60416 | reward 187.6
# it = 61440 | reward 55.1
# it = 62464 | reward 57.6
# it = 63488 | reward 50.1
# it = 64512 | reward 292.1
# it = 65536 | reward 239.7
# it = 66560 | reward 69.2
# it = 67584 | reward 61.4
# it = 68608 | reward 59.7
# it = 69632 | reward 66.7
# it = 70656 | reward 58.7
# it = 71680 | reward 75.7
# it = 72704 | reward 47.0
# it = 73728 | reward 56.3
# it = 74752 | reward 46.3
# it = 75776 | reward 55.0
# it = 76800 | reward 52.8
# it = 77824 | reward 66.5
# it = 78848 | reward 40.6
# it = 79872 | reward 51.8
# it = 80896 | reward 57.5
# it = 81920 | reward 85.9
# it = 82944 | reward 87.8
# it = 83968 | reward 135.3
# it = 84992 | reward 188.8
# it = 86016 | reward 50.7
# it = 87040 | reward 113.2
# it = 88064 | reward 58.2
# it = 89088 | reward 59.8
# it = 90112 | reward 51.6
# it = 91136 | reward 42.6
# it = 92160 | reward 47.2
# it = 93184 | reward 231.3
# it = 94208 | reward 159.8
# it = 95232 | reward 234.4
# it = 96256 | reward 366.1
# it = 97280 | reward 147.6
# it = 98304 | reward 242.5
# it = 99328 | reward 66.2
# it = 100352 | reward 236.5
# it = 101376 | reward 53.4
# it = 102400 | reward 153.7
# (101,)
# ======= run = 17 / 19 =========
# it = 1024 | reward 33.7
# it = 2048 | reward 35.6
# it = 3072 | reward 37.4
# it = 4096 | reward 46.6
# it = 5120 | reward 34.7
# it = 6144 | reward 38.9
# it = 7168 | reward 41.6
# it = 8192 | reward 44.8
# it = 9216 | reward 42.5
# it = 10240 | reward 47.7
# it = 11264 | reward 60.3
# it = 12288 | reward 49.5
# it = 13312 | reward 52.6
# it = 14336 | reward 50.9
# it = 15360 | reward 46.5
# it = 16384 | reward 96.1
# it = 17408 | reward 46.7
# it = 18432 | reward 60.2
# it = 19456 | reward 52.6
# it = 20480 | reward 40.3
# it = 21504 | reward 45.2
# it = 22528 | reward 190.0
# it = 23552 | reward 52.0
# it = 24576 | reward 40.8
# it = 25600 | reward 42.4
# it = 26624 | reward 40.2
# it = 27648 | reward 40.9
# it = 28672 | reward 40.3
# it = 29696 | reward 48.6
# it = 30720 | reward 66.3
# it = 31744 | reward 65.6
# it = 32768 | reward 60.1
# it = 33792 | reward 45.6
# it = 34816 | reward 50.4
# it = 35840 | reward 192.3
# it = 36864 | reward 47.2
# it = 37888 | reward 51.9
# it = 38912 | reward 155.8
# it = 39936 | reward 106.7
# it = 40960 | reward 42.9
# it = 41984 | reward 44.1
# it = 43008 | reward 126.2
# it = 44032 | reward 48.0
# it = 45056 | reward 44.1
# it = 46080 | reward 52.3
# it = 47104 | reward 50.6
# it = 48128 | reward 44.4
# it = 49152 | reward 60.9
# it = 50176 | reward 156.6
# it = 51200 | reward 48.2
# it = 52224 | reward 63.3
# it = 53248 | reward 56.2
# it = 54272 | reward 162.7
# it = 55296 | reward 61.8
# it = 56320 | reward 56.4
# it = 57344 | reward 41.1
# it = 58368 | reward 52.2
# it = 59392 | reward 42.1
# it = 60416 | reward 220.3
# it = 61440 | reward 249.3
# it = 62464 | reward 46.1
# it = 63488 | reward 45.1
# it = 64512 | reward 47.2
# it = 65536 | reward 58.8
# it = 66560 | reward 58.6
# it = 67584 | reward 52.0
# it = 68608 | reward 43.3
# it = 69632 | reward 326.7
# it = 70656 | reward 277.8
# it = 71680 | reward 209.9
# it = 72704 | reward 285.0
# it = 73728 | reward 53.1
# it = 74752 | reward 45.4
# it = 75776 | reward 54.1
# it = 76800 | reward 50.5
# it = 77824 | reward 61.3
# it = 78848 | reward 58.0
# it = 79872 | reward 165.1
# it = 80896 | reward 49.1
# it = 81920 | reward 54.9
# it = 82944 | reward 76.4
# it = 83968 | reward 112.0
# it = 84992 | reward 77.9
# it = 86016 | reward 49.7
# it = 87040 | reward 74.8
# it = 88064 | reward 118.9
# it = 89088 | reward 121.0
# it = 90112 | reward 53.9
# it = 91136 | reward 150.9
# it = 92160 | reward 48.4
# it = 93184 | reward 56.5
# it = 94208 | reward 47.3
# it = 95232 | reward 50.3
# it = 96256 | reward 72.5
# it = 97280 | reward 69.7
# it = 98304 | reward 125.3
# it = 99328 | reward 98.6
# it = 100352 | reward 78.5
# it = 101376 | reward 252.1
# it = 102400 | reward 70.1
# (101,)
# ======= run = 18 / 19 =========
# it = 1024 | reward 35.8
# it = 2048 | reward 48.2
# it = 3072 | reward 53.8
# it = 4096 | reward 52.0
# it = 5120 | reward 67.3
# it = 6144 | reward 46.9
# it = 7168 | reward 56.1
# it = 8192 | reward 64.3
# it = 9216 | reward 41.6
# it = 10240 | reward 40.9
# it = 11264 | reward 71.2
# it = 12288 | reward 51.3
# it = 13312 | reward 55.6
# it = 14336 | reward 52.1
# it = 15360 | reward 154.5
# it = 16384 | reward 94.7
# it = 17408 | reward 243.1
# it = 18432 | reward 103.1
# it = 19456 | reward 43.3
# it = 20480 | reward 48.1
# it = 21504 | reward 55.4
# it = 22528 | reward 43.9
# it = 23552 | reward 38.6
# it = 24576 | reward 45.0
# it = 25600 | reward 40.0
# it = 26624 | reward 49.4
# it = 27648 | reward 121.6
# it = 28672 | reward 123.4
# it = 29696 | reward 43.3
# it = 30720 | reward 51.4
# it = 31744 | reward 42.4
# it = 32768 | reward 56.5
# it = 33792 | reward 252.3
# it = 34816 | reward 106.0
# it = 35840 | reward 55.9
# it = 36864 | reward 46.4
# it = 37888 | reward 52.1
# it = 38912 | reward 170.1
# it = 39936 | reward 139.3
# it = 40960 | reward 38.5
# it = 41984 | reward 239.9
# it = 43008 | reward 289.9
# it = 44032 | reward 68.8
# it = 45056 | reward 109.5
# it = 46080 | reward 56.9
# it = 47104 | reward 161.5
# it = 48128 | reward 64.4
# it = 49152 | reward 102.5
# it = 50176 | reward 54.0
# it = 51200 | reward 58.9
# it = 52224 | reward 52.2
# it = 53248 | reward 51.4
# it = 54272 | reward 46.6
# it = 55296 | reward 49.7
# it = 56320 | reward 64.1
# it = 57344 | reward 60.0
# it = 58368 | reward 106.8
# it = 59392 | reward 50.6
# it = 60416 | reward 270.1
# it = 61440 | reward 90.4
# it = 62464 | reward 43.2
# it = 63488 | reward 46.2
# it = 64512 | reward 188.9
# it = 65536 | reward 146.2
# it = 66560 | reward 236.9
# it = 67584 | reward 363.8
# it = 68608 | reward 233.8
# it = 69632 | reward 39.0
# it = 70656 | reward 47.8
# it = 71680 | reward 46.6
# it = 72704 | reward 37.1
# it = 73728 | reward 50.3
# it = 74752 | reward 43.7
# it = 75776 | reward 65.9
# it = 76800 | reward 51.5
# it = 77824 | reward 318.4
# it = 78848 | reward 56.5
# it = 79872 | reward 197.1
# it = 80896 | reward 67.5
# it = 81920 | reward 178.4
# it = 82944 | reward 298.8
# it = 83968 | reward 201.2
# it = 84992 | reward 49.6
# it = 86016 | reward 101.0
# it = 87040 | reward 160.7
# it = 88064 | reward 151.7
# it = 89088 | reward 318.0
# it = 90112 | reward 67.8
# it = 91136 | reward 47.5
# it = 92160 | reward 161.6
# it = 93184 | reward 48.3
# it = 94208 | reward 41.3
# it = 95232 | reward 37.8
# it = 96256 | reward 53.0
# it = 97280 | reward 43.3
# it = 98304 | reward 53.0
# it = 99328 | reward 47.8
# it = 100352 | reward 325.5
# it = 101376 | reward 120.7
# it = 102400 | reward 81.2
# (101,)
# ======= run = 19 / 19 =========
# it = 1024 | reward 43.7
# it = 2048 | reward 44.4
# it = 3072 | reward 42.7
# it = 4096 | reward 61.7
# it = 5120 | reward 40.1
# it = 6144 | reward 49.3
# it = 7168 | reward 46.2
# it = 8192 | reward 46.9
# it = 9216 | reward 116.3
# it = 10240 | reward 48.0
# it = 11264 | reward 51.0
# it = 12288 | reward 47.3
# it = 13312 | reward 36.8
# it = 14336 | reward 96.1
# it = 15360 | reward 41.6
# it = 16384 | reward 46.5
# it = 17408 | reward 59.1
# it = 18432 | reward 275.0
# it = 19456 | reward 331.7
# it = 20480 | reward 44.6
# it = 21504 | reward 65.4
# it = 22528 | reward 201.1
# it = 23552 | reward 99.0
# it = 24576 | reward 115.1
# it = 25600 | reward 48.7
# it = 26624 | reward 124.6
# it = 27648 | reward 48.4
# it = 28672 | reward 129.4
# it = 29696 | reward 47.5
# it = 30720 | reward 82.5
# it = 31744 | reward 76.6
# it = 32768 | reward 100.9
# it = 33792 | reward 80.1
# it = 34816 | reward 50.7
# it = 35840 | reward 49.5
# it = 36864 | reward 47.0
# it = 37888 | reward 50.2
# it = 38912 | reward 47.0
# it = 39936 | reward 44.8
# it = 40960 | reward 89.5
# it = 41984 | reward 180.8
# it = 43008 | reward 179.4
# it = 44032 | reward 238.6
# it = 45056 | reward 274.3
# it = 46080 | reward 171.3
# it = 47104 | reward 64.7
# it = 48128 | reward 196.6
# it = 49152 | reward 98.7
# it = 50176 | reward 50.5
# it = 51200 | reward 50.2
# it = 52224 | reward 68.1
# it = 53248 | reward 75.8
# it = 54272 | reward 291.1
# it = 55296 | reward 224.9
# it = 56320 | reward 235.3
# it = 57344 | reward 275.6
# it = 58368 | reward 44.1
# it = 59392 | reward 108.3
# it = 60416 | reward 51.2
# it = 61440 | reward 149.7
# it = 62464 | reward 50.0
# it = 63488 | reward 61.1
# it = 64512 | reward 64.4
# it = 65536 | reward 145.1
# it = 66560 | reward 263.8
# it = 67584 | reward 84.5
# it = 68608 | reward 120.0
# it = 69632 | reward 172.7
# it = 70656 | reward 368.5
# it = 71680 | reward 166.2
# it = 72704 | reward 103.2
# it = 73728 | reward 250.6
# it = 74752 | reward 44.0
# it = 75776 | reward 237.9
# it = 76800 | reward 87.8
# it = 77824 | reward 110.2
# it = 78848 | reward 318.7
# it = 79872 | reward 54.1
# it = 80896 | reward 168.5
# it = 81920 | reward 307.4
# it = 82944 | reward 64.5
# it = 83968 | reward 53.8
# it = 84992 | reward 48.8
# it = 86016 | reward 61.4
# it = 87040 | reward 104.5
# it = 88064 | reward 233.0
# it = 89088 | reward 240.9
# it = 90112 | reward 269.8
# it = 91136 | reward 86.4
# it = 92160 | reward 218.8
# it = 93184 | reward 36.6
# it = 94208 | reward 34.9
# it = 95232 | reward 42.5
# it = 96256 | reward 45.6
# it = 97280 | reward 38.4
# it = 98304 | reward 37.1
# it = 99328 | reward 40.9
# it = 100352 | reward 37.0
# it = 101376 | reward 49.6
# it = 102400 | reward 39.5
# (101,)

# %%
rec_env = wrap_env(TimeLimit(ContinuousEnvCACLA(render_mode='rgb_array'),max_episode_steps=500))
observation, _ = rec_env.reset()
maxEvaluations = 2
evaluation = 0
score = []
total = 0
while evaluation < maxEvaluations:
    rec_env.render()
    _, a0 = gav(observation)  
    action = a0
    observation, reward, done, truncated, _ = rec_env.step(action) 
    total += reward
    if done or truncated:
      score.append(total)
      total = 0
      evaluation = evaluation + 1
      observation, _ = rec_env.reset()
rec_env.close()
score
# Out:
# Moviepy - Building video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-0.mp4.
# Moviepy - Writing video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-0.mp4
# Moviepy - Building video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-1.mp4.
# Moviepy - Writing video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-1.mp4
# Moviepy - Building video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-2.mp4.
# Moviepy - Writing video /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-2.mp4
# Moviepy - Done !
# Moviepy - video ready /users/nfs/Etu3/28604113/IAR/PROJET_IAR/ddpg_gav/videoTest/rl-video-episode-2.mp4
# [500.0, 500.0]

# %%
show_video(num=0)
# Out:
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:videoTest/mp4;base64,..." type="video/mp4" />
#                  </video>
